# %% [markdown]
# # Analyzing Medical DataSet - Question 2
#
# In this Notebook I will try to analyze the following dataset to solve both **question2** of the **TMA**.

# %% [markdown]
# ## Representing Diabetes Dataset

# %% [markdown]
# ### Introduction
#
# This dataset offers a detailed view of multiple diabetes types, such as Steroid-Induced Diabetes, NDM, Prediabetes, Type 1 Diabetes, and Wolfram Syndrome. Also, it covers essential medical, genetic, and lifestyle factors crucial for understanding diabetes-related influences.
#
# Now, I will represent the component of the Diabetes dataset.

# %% [markdown]
# ### Displaying Data from Diabetes Dataset

# %%
# It's important to represent the libraries that may be needed.
import pandas as pd
import numpy as np

# %%
# Now I will load the dataset and represent it.
diabetes_dataset = pd.read_csv('diabetes_dataset00.csv')
diabetes_dataset
# Out:
#                                            Target Genetic Markers  \
# 0                        Steroid-Induced Diabetes        Positive
# 1                Neonatal Diabetes Mellitus (NDM)        Positive
# 2                                     Prediabetic        Positive
# 3                                 Type 1 Diabetes        Negative
# 4                                Wolfram Syndrome        Negative
# 5                                            LADA        Positive
# 6                                 Type 2 Diabetes        Negative
# 7                       Wolcott-Rallison Syndrome        Positive
# 8                              Secondary Diabetes        Negative
# 9                              Secondary Diabetes        Positive
# 10                             Secondary Diabetes        Negative
# 11                                Type 1 Diabetes        Positive
# 12                                    Prediabetic        Positive
# ...

# %%
# The first five rows of the dataset
print('\nThe first five rows of the Diabetes Dataset: ')
diabetes_dataset.head()
# Out:
# The first five rows of the Diabetes Dataset:
#                              Target Genetic Markers Autoantibodies  \
# 0          Steroid-Induced Diabetes        Positive       Negative
# 1  Neonatal Diabetes Mellitus (NDM)        Positive       Negative
# 2                       Prediabetic        Positive       Positive
# 3                   Type 1 Diabetes        Negative       Positive
# 4                  Wolfram Syndrome        Negative       Negative
#
#   Family History Environmental Factors  Insulin Levels  Age  BMI  \
# 0             No               Present              40   44   38
# 1             No               Present              13    1   17
# 2            Yes               Present              27   36   24
# 3             No               Present               8    7   16
# 4            Yes               Present              17   10   17
#
#   Physical Activity Dietary Habits         ...           Pulmonary Function  \
# ...

# %% [markdown]
# The previous code display the first rows and last rows of the *diabetes_dataset.csv* file. The dataset includes 70000 entries and 34 columns, each providing specific information related to diabetes types and associated medical, genetic, and lifestyle attributes.

# %%
# For more understanding of the strucure of the dataset.
print('\nDiabetes Dataset Information: ')
diabetes_dataset.info()
# Out:
# Diabetes Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 34 columns):
# Target                           70000 non-null object
# Genetic Markers                  70000 non-null object
# Autoantibodies                   70000 non-null object
# Family History                   70000 non-null object
# Environmental Factors            70000 non-null object
# Insulin Levels                   70000 non-null int64
# Age                              70000 non-null int64
# BMI                              70000 non-null int64
# Physical Activity                70000 non-null object
# Dietary Habits                   70000 non-null object
# Blood Pressure                   70000 non-null int64
# Cholesterol Levels               70000 non-null int64
# Waist Circumference              70000 non-null int64
# Blood Glucose Levels             70000 non-null int64
# Ethnicity                        70000 non-null object
# ...

# %%
diabetes_dataset.describe(include='all')
# Out:
#        Target Genetic Markers Autoantibodies Family History  \
# count   70000           70000          70000          70000
# unique     13               2              2              2
# top      MODY        Positive       Negative            Yes
# freq     5553           35101          35058          35168
# mean      NaN             NaN            NaN            NaN
# std       NaN             NaN            NaN            NaN
# min       NaN             NaN            NaN            NaN
# 25%       NaN             NaN            NaN            NaN
# 50%       NaN             NaN            NaN            NaN
# 75%       NaN             NaN            NaN            NaN
# max       NaN             NaN            NaN            NaN
#
#        Environmental Factors  Insulin Levels           Age           BMI  \
# count                  70000    70000.000000  70000.000000  70000.000000
# unique                     2             NaN           NaN           NaN
# ...

# %%
# count the number of entries to check whether there is null values or not.
diabetes_dataset.count()
# Out:
# Target                           70000
# Genetic Markers                  70000
# Autoantibodies                   70000
# Family History                   70000
# Environmental Factors            70000
# Insulin Levels                   70000
# Age                              70000
# BMI                              70000
# Physical Activity                70000
# Dietary Habits                   70000
# Blood Pressure                   70000
# Cholesterol Levels               70000
# Waist Circumference              70000
# Blood Glucose Levels             70000
# Ethnicity                        70000
# Socioeconomic Factors            70000
# Smoking Status                   70000
# Alcohol Consumption              70000
# Glucose Tolerance Test           70000
# History of PCOS                  70000
# Previous Gestational Diabetes    70000
# Pregnancy History                70000
# Weight Gain During Pregnancy     70000
# Pancreatic Health                70000
# ...

# %%
# Now to check whether the data is consistency or not I'll check the duplication.
diabetes_dataset.duplicated().sum()
# Out:
# 0
